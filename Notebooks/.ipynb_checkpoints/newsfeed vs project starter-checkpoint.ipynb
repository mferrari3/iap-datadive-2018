# %% [markdown]
# # import the necessary package

# %%
import pandas as pd
import pickle
import random
pd.set_option('display.max_columns',100)
# %matplotlib inline

from scipy import spatial
import numpy as np
import spacy
from spacy import displacy
from geotext import GeoText

# %% [markdown]
# # load the dataset

# %% [markdown]
# **News Articles **

# %% [markdown]
# This is the "raw" newsdeed data that we want to try to match with projects. If you run into a protocol error try the '_py27.pkl' version

# %%
news_data = pd.read_pickle('../Data/Feedly_Processed_DF_cleaned.pkl')

# %% [markdown]
# Note that the third item's `title` field looks to have a lot of content - there is likely cleaning needed on some of these fields.

# %%
news_data.head(3)
# Out:
#       article_id                                              title  \
# 10900   eebb9702  India, World Bank sign financing agreement for...
# 4268    6832ce57  Rs 40000-crore development projects in limbo i...
# 1663    30f8f65e  https://www.the-american-interest.com/2018/01/...
#
#                                                      url  \
# 10900  http://www.abplive.in/business/india-world-ban...
# 4268   http://www.moneycontrol.com/news/business/econ...
# 1663   https://www.the-american-interest.com/2018/01/...
#
#                     feed_label content           published  \
# 10900     NEWS WB- All Streams     NaN 2017-12-21 09:22:12
# 4268   NEWS AIIB - All Streams     NaN 2017-12-10 09:40:00
# 1663    NEWS AFDB- All Streams     NaN 2018-01-03 12:21:54
#
#                                                  summary  \
# 10900  <table border="0" cellspacing="3" cellpadding=...
# 4268   <table border="0" cellspacing="3" cellpadding=...
# 1663   <table border="0" cellspacing="3" cellpadding=...
#
#                                             article_text  \
# 10900  New Delhi [India], Dec 20 (ANI): A financing a...
# 4268   Development projects worth more than Rs 40,000...
# 1663   Ten Lessons\n\nDevelopment with Chinese Charac...
#
#                                         article_keywords  article_text_len  \
# 10900  [institutes, india, skill, financing, training...              1031
# 4268   [development, crore, andhra, eaps, state, proj...              4390
# 1663   [transitions, university, chinese, united, dev...               575
#
#       top_lang
# 10900       en
# 4268        en
# 1663        en

# %%
news_data.columns
# Out:
# Index(['article_id', 'title', 'url', 'feed_label', 'content', 'published',
#        'summary', 'article_text', 'article_keywords', 'article_text_len',
#        'top_lang'],
#       dtype='object')

# %% [markdown]
# ** Projcets Data **

# %% [markdown]
# This is the "raw" unmatched project data

# %%
project_info = pd.read_csv('../Data/EWS_Published Project_Listing_DD.csv',encoding='ISO-8859-1')

# %%
project_info.head(3)
# Out:
#    EWS ID      ProjectNumber  Published Bank Risk Rating Project Status  \
# 0   29164  AFDB-P-TN-BB0-007  Published                U       Proposed
# 1   29166  AFDB-P-SZ-HAA-001  Published                U       Approved
# 2   29931      IADB-UR-T1100    Pending                C       Approved
#
#                                              EWS URL  Detailed Analysis URL  \
# 0  https://ews.rightsindevelopment.org/projects/p...                    NaN
# 1  https://ews.rightsindevelopment.org/projects/p...                    NaN
# 2  https://ews.rightsindevelopment.org/projects/u...                    NaN
#
#                                         Project Name City  Country Count  \
# 0                         TUNISIA FERTILIZER PROJECT  NaN              1
# 1  LINE OF CREDIT TO SWAZILAND DEVELOPMENT FINANC...  NaN              1
# 2  Supporting INEFOP in Improving Labor Training ...  NaN              1
#
#    Country 1 Country 2 Country 3 Country 4 Country 5 Country 6 Country 7  \
# 0    Tunisia       NaN       NaN       NaN       NaN       NaN       NaN
# 1  Swaziland       NaN       NaN       NaN       NaN       NaN       NaN
# 2    Uruguay       NaN       NaN       NaN       NaN       NaN       NaN
#
#   Country 8 Country 9 Country 10 Country 11 Country 12 Borrower or Client  \
# 0       NaN       NaN        NaN        NaN        NaN                NaN
# 1       NaN       NaN        NaN        NaN        NaN                NaN
# 2       NaN       NaN        NaN        NaN        NaN                NaN
#
#    Private Actor Count Private Actor 1 Private Actor 2 Private Actor 3  \
# 0                  0.0             NaN             NaN             NaN
# 1                  0.0             NaN             NaN             NaN
# 2                  0.0             NaN             NaN             NaN
#
#   Private Actor 4 Private Actor 5 Private Actor 6 Private Actor 7  \
# 0             NaN             NaN             NaN             NaN
# 1             NaN             NaN             NaN             NaN
# 2             NaN             NaN             NaN             NaN
#
#   Private Actor 8  Private Actor 9  Private Actor 10  Private Actor 11  \
# 0             NaN              NaN               NaN               NaN
# 1             NaN              NaN               NaN               NaN
# 2             NaN              NaN               NaN               NaN
#
#    Private Actor 12  Private Actor 13  Private Actor 14  Private Actor 15  \
# 0               NaN               NaN               NaN               NaN
# 1               NaN               NaN               NaN               NaN
# 2               NaN               NaN               NaN               NaN
#
#    Bank Count                                  Bank 1 Bank 2 Bank 3 Bank 4  \
# 0           1         African Development Bank (AFDB)    NaN    NaN    NaN
# 1           1         African Development Bank (AFDB)    NaN    NaN    NaN
# 2           1  Inter-American Development Bank (IADB)    NaN    NaN    NaN
#
#    Bank 5  Sector Count                  Sector 1            Sector 2  \
# 0     NaN             1  Agriculture and Forestry                 NaN
# 1     NaN             2                   Finance  Industry and Trade
# 2     NaN             0                       NaN                 NaN
#
#   Sector 3 Sector 4 Sector 5 Sector 6 Sector 7 Last Edited Date Scraped  \
# 0      NaN      NaN      NaN      NaN      NaN      9/4/17      8/15/17
# 1      NaN      NaN      NaN      NaN      NaN      9/4/17      8/15/17
# 2      NaN      NaN      NaN      NaN      NaN         NaN      10/3/17
#
#   Date Disclosed Board Date  \
# 0       12/13/01   12/13/01
# 1       12/13/01    5/12/17
# 2       12/31/99    7/16/13
#
#                                           Source URL  Project Cost  \
# 0  http://www.afdb.org/en/projects-and-operations...           NaN
# 1  http://www.afdb.org/en/projects-and-operations...          4.76
# 2  http://www.iadb.org/en/projects/project-descri...          0.44
#
#    Investment Amount Project Description  \
# 0                NaN                None
# 1               1.36                None
# 2               0.44                 NaN
#
#                                  Contact Information
# 0  ACCOUNTABILITY MECHANISM OF AfDB\r\r\r\rThe In...
# 1  MACHARIA Lilian Wanjiru - PIFD1\r\r\r\rACCOUNT...
# 2                                                NaN

# %%
project_info.columns
# Out:
# Index(['EWS ID', 'ProjectNumber', 'Published', 'Bank Risk Rating',
#        'Project Status', 'EWS URL', 'Detailed Analysis URL', 'Project Name',
#        'City', 'Country Count', 'Country 1', 'Country 2', 'Country 3',
#        'Country 4', 'Country 5', 'Country 6', 'Country 7', 'Country 8',
#        'Country 9', 'Country 10', 'Country 11', 'Country 12',
#        'Borrower or Client', 'Private Actor Count', 'Private Actor 1',
#        'Private Actor 2', 'Private Actor 3', 'Private Actor 4',
#        'Private Actor 5', 'Private Actor 6', 'Private Actor 7',
#        'Private Actor 8', 'Private Actor 9', 'Private Actor 10',
#        'Private Actor 11', 'Private Actor 12', 'Private Actor 13',
#        'Private Actor 14', 'Private Actor 15', 'Bank Count', 'Bank 1',
#        'Bank 2', 'Bank 3', 'Bank 4', 'Bank 5', 'Sector Count', 'Sector 1',
#        'Sector 2', 'Sector 3', 'Sector 4', 'Sector 5', 'Sector 6', 'Sector 7',
#        'Last Edited', 'Date Scraped', 'Date Disclosed', 'Board Date',
#        'Source URL', 'Project Cost', 'Investment Amount',
#        'Project Description', 'Contact Information'],
#       dtype='object')

# %% [markdown]
# **Labeled Projcet Data **

# %% [markdown]
# There isn't much of this data - so it is wise to treat this as a test/validation set for any algorithm you develop. Perhaps you can use a small sample of this data to build intuition for designing your algorithm.

# %%
projects_labeled = pd.read_csv('../Data/Labeled_Data/projects.csv',encoding='ISO-8859-1')

# %%
projects_labeled.head(3)
# Out:
#   article_id published                                              title  \
# 0    10f9ed2   1/11/18  ADB Provides Support for Three Infrastructure ...
# 1   c0eece9b   5/13/18  ADB Helps Inaugurate New Power Distribution Ne...
# 2   d1d79dd8   2/20/18  ADB Provides $360 Million for Rolling Stock to...
#
#                                                  url              feed_label  \
# 0  http://moderndiplomacy.eu/2018/01/11/adb-provi...  NEWS ADB - All Streams
# 1  http://feedproxy.google.com/~r/adb_news/~3/2My...  NEWS ADB - All Streams
# 2  http://feedproxy.google.com/~r/adb_news/~3/v9s...  NEWS ADB - All Streams
#
#                                  ProjectNumber  \
# 0  ADB-41123-015, ADB-48158-001, ADB-41435-053
# 1                                ADB-47282-001
# 2                                ADB-50312-003
#
#                                     EWS Project Name  \
# 0  Road Network Improvement Project (formerly Sec...
# 1  Energy Supply Improvement Investment Program (...
# 2  Railway Rolling Stock Operations Improvement P...
#
#                                        EWS hyperlink  Matched
# 0  https://ewsdata.rightsindevelopment.org/projec...        1
# 1  https://ewsdata.rightsindevelopment.org/projec...        1
# 2  https://ewsdata.rightsindevelopment.org/projec...        1

# %% [markdown]
# # Possible Places to Start
#
# 1. Extract features from the News Articles and the raw Projects data (bank, keywords, country etc). From news article with extract the banks from feed_label. feed_label is from news article.
#
# 2. Maybe start with title and banks - see if you are getting any matches that make sense.

# %%
project_info.columns
# Out:
# Index(['EWS ID', 'ProjectNumber', 'Published', 'Bank Risk Rating',
#        'Project Status', 'EWS URL', 'Detailed Analysis URL', 'Project Name',
#        'City', 'Country Count', 'Country 1', 'Country 2', 'Country 3',
#        'Country 4', 'Country 5', 'Country 6', 'Country 7', 'Country 8',
#        'Country 9', 'Country 10', 'Country 11', 'Country 12',
#        'Borrower or Client', 'Private Actor Count', 'Private Actor 1',
#        'Private Actor 2', 'Private Actor 3', 'Private Actor 4',
#        'Private Actor 5', 'Private Actor 6', 'Private Actor 7',
#        'Private Actor 8', 'Private Actor 9', 'Private Actor 10',
#        'Private Actor 11', 'Private Actor 12', 'Private Actor 13',
#        'Private Actor 14', 'Private Actor 15', 'Bank Count', 'Bank 1',
#        'Bank 2', 'Bank 3', 'Bank 4', 'Bank 5', 'Sector Count', 'Sector 1',
#        'Sector 2', 'Sector 3', 'Sector 4', 'Sector 5', 'Sector 6', 'Sector 7',
#        'Last Edited', 'Date Scraped', 'Date Disclosed', 'Board Date',
#        'Source URL', 'Project Cost', 'Investment Amount',
#        'Project Description', 'Contact Information'],
#       dtype='object')

# %%
project_info['Project Description'].head()
# Out:
# 0    None
# 1    None
# 2     NaN
# 3     NaN
# 4     NaN
# Name: Project Description, dtype: object

# %%
project_info.head()
# Out:
#    EWS ID      ProjectNumber  Published Bank Risk Rating Project Status  \
# 0   29164  AFDB-P-TN-BB0-007  Published                U       Proposed
# 1   29166  AFDB-P-SZ-HAA-001  Published                U       Approved
# 2   29931      IADB-UR-T1100    Pending                C       Approved
# 3   30104      IADB-BR-T1279    Pending                C       Approved
# 4   30322      IADB-PE-T1297    Pending                C       Approved
#
#                                              EWS URL  Detailed Analysis URL  \
# 0  https://ews.rightsindevelopment.org/projects/p...                    NaN
# 1  https://ews.rightsindevelopment.org/projects/p...                    NaN
# 2  https://ews.rightsindevelopment.org/projects/u...                    NaN
# 3  https://ews.rightsindevelopment.org/projects/b...                    NaN
# 4  https://ews.rightsindevelopment.org/projects/p...                    NaN
#
#                                         Project Name City  Country Count  \
# 0                         TUNISIA FERTILIZER PROJECT  NaN              1
# 1  LINE OF CREDIT TO SWAZILAND DEVELOPMENT FINANC...  NaN              1
# 2  Supporting INEFOP in Improving Labor Training ...  NaN              1
# 3  Racial Equality and Social, Economic, Politica...  NaN              1
# 4  Adaptation to Climate Change of the Fishery Se...  NaN              1
#
#    Country 1 Country 2 Country 3 Country 4 Country 5 Country 6 Country 7  \
# 0    Tunisia       NaN       NaN       NaN       NaN       NaN       NaN
# 1  Swaziland       NaN       NaN       NaN       NaN       NaN       NaN
# 2    Uruguay       NaN       NaN       NaN       NaN       NaN       NaN
# 3     Brazil       NaN       NaN       NaN       NaN       NaN       NaN
# 4       Peru       NaN       NaN       NaN       NaN       NaN       NaN
#
#   Country 8 Country 9 Country 10 Country 11 Country 12 Borrower or Client  \
# 0       NaN       NaN        NaN        NaN        NaN                NaN
# 1       NaN       NaN        NaN        NaN        NaN                NaN
# 2       NaN       NaN        NaN        NaN        NaN                NaN
# 3       NaN       NaN        NaN        NaN        NaN                NaN
# 4       NaN       NaN        NaN        NaN        NaN                NaN
#
#    Private Actor Count Private Actor 1 Private Actor 2 Private Actor 3  \
# 0                  0.0             NaN             NaN             NaN
# 1                  0.0             NaN             NaN             NaN
# 2                  0.0             NaN             NaN             NaN
# 3                  0.0             NaN             NaN             NaN
# 4                  0.0             NaN             NaN             NaN
#
#   Private Actor 4 Private Actor 5 Private Actor 6 Private Actor 7  \
# 0             NaN             NaN             NaN             NaN
# 1             NaN             NaN             NaN             NaN
# 2             NaN             NaN             NaN             NaN
# 3             NaN             NaN             NaN             NaN
# 4             NaN             NaN             NaN             NaN
#
#   Private Actor 8  Private Actor 9  Private Actor 10  Private Actor 11  \
# 0             NaN              NaN               NaN               NaN
# 1             NaN              NaN               NaN               NaN
# 2             NaN              NaN               NaN               NaN
# 3             NaN              NaN               NaN               NaN
# 4             NaN              NaN               NaN               NaN
#
#    Private Actor 12  Private Actor 13  Private Actor 14  Private Actor 15  \
# 0               NaN               NaN               NaN               NaN
# 1               NaN               NaN               NaN               NaN
# 2               NaN               NaN               NaN               NaN
# 3               NaN               NaN               NaN               NaN
# 4               NaN               NaN               NaN               NaN
#
#    Bank Count                                  Bank 1 Bank 2 Bank 3 Bank 4  \
# 0           1         African Development Bank (AFDB)    NaN    NaN    NaN
# 1           1         African Development Bank (AFDB)    NaN    NaN    NaN
# 2           1  Inter-American Development Bank (IADB)    NaN    NaN    NaN
# 3           1  Inter-American Development Bank (IADB)    NaN    NaN    NaN
# 4           1  Inter-American Development Bank (IADB)    NaN    NaN    NaN
#
#    Bank 5  Sector Count                  Sector 1            Sector 2  \
# 0     NaN             1  Agriculture and Forestry                 NaN
# 1     NaN             2                   Finance  Industry and Trade
# 2     NaN             0                       NaN                 NaN
# 3     NaN             0                       NaN                 NaN
# 4     NaN             0                       NaN                 NaN
#
#   Sector 3 Sector 4 Sector 5 Sector 6 Sector 7 Last Edited Date Scraped  \
# 0      NaN      NaN      NaN      NaN      NaN      9/4/17      8/15/17
# 1      NaN      NaN      NaN      NaN      NaN      9/4/17      8/15/17
# 2      NaN      NaN      NaN      NaN      NaN         NaN      10/3/17
# 3      NaN      NaN      NaN      NaN      NaN         NaN      10/3/17
# 4      NaN      NaN      NaN      NaN      NaN         NaN      10/3/17
#
#   Date Disclosed Board Date  \
# 0       12/13/01   12/13/01
# 1       12/13/01    5/12/17
# 2       12/31/99    7/16/13
# 3       12/31/99     6/4/13
# 4       12/31/99    12/4/13
#
#                                           Source URL  Project Cost  \
# 0  http://www.afdb.org/en/projects-and-operations...           NaN
# 1  http://www.afdb.org/en/projects-and-operations...          4.76
# 2  http://www.iadb.org/en/projects/project-descri...          0.44
# 3  http://www.iadb.org/en/projects/project-descri...          0.97
# 4  http://www.iadb.org/en/projects/project-descri...          1.50
#
#    Investment Amount Project Description  \
# 0                NaN                None
# 1               1.36                None
# 2               0.44                 NaN
# 3               0.82                 NaN
# 4               1.50                 NaN
#
#                                  Contact Information
# 0  ACCOUNTABILITY MECHANISM OF AfDB\r\r\r\rThe In...
# 1  MACHARIA Lilian Wanjiru - PIFD1\r\r\r\rACCOUNT...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN

# %%
sentence = project_info.iloc[6809]['Project Description']

# %%
nlp = spacy.load('en')

# %%
doc = nlp(sentence)
doc
# Out:
# The project's objective is to provide the necessary conditions for the growth and competitiveness of businesses in Paraguay by supporting a network of impact oriented companies.

# %% [markdown]
# Detect sentences:

# %%
for sent in doc.sents:
    print(sent)
# Out:
# The project's objective is to provide the necessary conditions for the growth and competitiveness of businesses in Paraguay by supporting a network of impact oriented companies.

# %%
print([(token.text, token.tag_) for token in doc])
# Out:
# [('The', 'DT'), ('project', 'NN'), ("'s", 'POS'), ('objective', 'NN'), ('is', 'VBZ'), ('to', 'TO'), ('provide', 'VB'), ('the', 'DT'), ('necessary', 'JJ'), ('conditions', 'NNS'), ('for', 'IN'), ('the', 'DT'), ('growth', 'NN'), ('and', 'CC'), ('competitiveness', 'NN'), ('of', 'IN'), ('businesses', 'NNS'), ('in', 'IN'), ('Paraguay', 'NNP'), ('by', 'IN'), ('supporting', 'VBG'), ('a', 'DT'), ('network', 'NN'), ('of', 'IN'), ('impact', 'NN'), ('oriented', 'VBN'), ('companies', 'NNS'), ('.', '.')]

# %%
for ent in doc.ents:
    print(ent.text, ent.label_)
# Out:
# Paraguay ORG

# %%
doc = nlp(sentence)
displacy.render(doc, style='ent', jupyter=True)
# Out:
# <div class="entities" style="line-height: 2.5">The project's objective is to provide the necessary conditions for the growth and competitiveness of businesses in
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Paraguay
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  by supporting a network of impact oriented companies.</div>

# %%
for chunk in doc.noun_chunks:
    print(chunk.text, chunk.label_, chunk.root.text)
    print(" ")
# Out:
# The project's objective NP objective
#
# the necessary conditions NP conditions
#
# the growth NP growth
#
# competitiveness NP competitiveness
#
# businesses NP businesses
#
# Paraguay NP Paraguay
#
# a network NP network
#
# impact oriented companies NP companies

# %%
for token in doc:
    print("{}/{} <--{}-- {}/{}".format(token.text, 
                                      token.tag_,
                                      token.dep_,
                                      token.head.text,
                                      token.head.tag_))
# Out:
# The/DT <--det-- project/NN
# project/NN <--poss-- objective/NN
# 's/POS <--case-- project/NN
# objective/NN <--nsubj-- is/VBZ
# is/VBZ <--ROOT-- is/VBZ
# to/TO <--aux-- provide/VB
# provide/VB <--xcomp-- is/VBZ
# the/DT <--det-- conditions/NNS
# necessary/JJ <--amod-- conditions/NNS
# conditions/NNS <--dobj-- provide/VB
# for/IN <--prep-- conditions/NNS
# the/DT <--det-- growth/NN
# growth/NN <--pobj-- for/IN
# and/CC <--cc-- growth/NN
# competitiveness/NN <--conj-- growth/NN
# of/IN <--prep-- growth/NN
# businesses/NNS <--pobj-- of/IN
# in/IN <--prep-- growth/NN
# Paraguay/NNP <--pobj-- in/IN
# by/IN <--prep-- provide/VB
# supporting/VBG <--pcomp-- by/IN
# a/DT <--det-- network/NN
# network/NN <--dobj-- supporting/VBG
# of/IN <--prep-- network/NN
# impact/NN <--npadvmod-- oriented/VBN
# oriented/VBN <--amod-- companies/NNS
# companies/NNS <--pobj-- of/IN
# ./. <--punct-- is/VBZ

# %%
displacy.render(doc, style='dep', jupyter=True, options={'distance': 90})
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="0" class="displacy" width="2480" height="362.0" style="max-width: none; height: 362.0px; color: #000000; background: #ffffff; font-family: Arial">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">The</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="140">project</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="140">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="230">'s</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="230">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="320">objective</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="320">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="410">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="410">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="500">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="500">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="590">provide</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="590">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="680">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="680">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">necessary</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="860">conditions</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="860">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="950">for</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="950">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="1040">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1040">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="1130">growth</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1130">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="1220">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1220">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="1310">competitiveness</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1310">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="1400">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1400">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="1490">businesses</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1490">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="1580">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1580">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="1670">Paraguay</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1670">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="1760">by</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1760">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">supporting</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="1940">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1940">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="2030">network</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2030">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="2120">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2120">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="2210">impact</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2210">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="2300">oriented</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2300">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="2390">companies.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2390">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-0" stroke-width="2px" d="M70,227.0 C70,182.0 120.0,182.0 120.0,227.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-0" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,229.0 L62,217.0 78,217.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-1" stroke-width="2px" d="M160,227.0 C160,137.0 305.0,137.0 305.0,227.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-1" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">poss</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M160,229.0 L152,217.0 168,217.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="ar

# %%
nlp = spacy.load('en_core_web_lg')

# %%
np.dot(nlp.vocab['chiquita'].vector, nlp.vocab['banana'].vector)
# Out:
# 14.928883

# %%
cosine_similarity = lambda x, y: 1 - spatial.distance.cosine(x, y)

# %%
man = nlp.vocab['man'].vector
woman = nlp.vocab['woman'].vector
queen = nlp.vocab['queen'].vector
king = nlp.vocab['king'].vector

# %%
# We now need to find the closest vector in the vocabulary to the 
# result of "man" - "woman" + "queen"
maybe_king =  man - woman + queen

# %%
computed_similarities = []
for word in nlp.vocab:
    #ignore words wo vectors
    if not word.has_vector:
        continue
    similarity = cosine_similarity(maybe_king, word.vector)
    computed_similarities.append((word, similarity))

# %%
computed_similarities = sorted(computed_similarities, key=lambda item: -item[1])

# %%
print([w[0].text for w in computed_similarities[:10]])
# Out:
# ['Queen', 'QUEEN', 'queen', 'King', 'KING', 'king', 'KIng', 'Kings', 'KINGS', 'kings']

# %%
news_sentence = nlp(news_data.iloc[4268]['article_text'])

# %%
project_description = nlp(sentence)

# %%
project_description.similarity(news_sentence)
# Out:
# 0.9317586846877413

# %%
news_data.columns
# Out:
# Index(['article_id', 'title', 'url', 'feed_label', 'content', 'published',
#        'summary', 'article_text', 'article_keywords', 'article_text_len',
#        'top_lang'],
#       dtype='object')

# %%
nlp

# %%
article = news_data.iloc[7463]['article_text']

# %%
article = news_data.iloc[5173]['article_text']

# %%
news_data.head()
# Out:
#       article_id                                              title  \
# 10900   eebb9702  India, World Bank sign financing agreement for...
# 4268    6832ce57  Rs 40000-crore development projects in limbo i...
# 1663    30f8f65e  https://www.the-american-interest.com/2018/01/...
# 3789    5ec16472  $300 Million to Expand and Upgrade Infrastruct...
# 6657    989c9942  ADB Provides $346 Million to Upgrade State Hig...
#
#                                                      url  \
# 10900  http://www.abplive.in/business/india-world-ban...
# 4268   http://www.moneycontrol.com/news/business/econ...
# 1663   https://www.the-american-interest.com/2018/01/...
# 3789   https://jis.gov.jm/300-million-to-expand-and-u...
# 6657   http://www.business-standard.com/article/news-...
#
#                     feed_label content           published  \
# 10900     NEWS WB- All Streams     NaN 2017-12-21 09:22:12
# 4268   NEWS AIIB - All Streams     NaN 2017-12-10 09:40:00
# 1663    NEWS AFDB- All Streams     NaN 2018-01-03 12:21:54
# 3789    NEWS IDB - All Streams     NaN 2018-04-27 16:28:43
# 6657    NEWS ADB - All Streams     NaN 2017-12-10 01:00:00
#
#                                                  summary  \
# 10900  <table border="0" cellspacing="3" cellpadding=...
# 4268   <table border="0" cellspacing="3" cellpadding=...
# 1663   <table border="0" cellspacing="3" cellpadding=...
# 3789   <table border="0" cellspacing="3" cellpadding=...
# 6657   <table border="0" cellspacing="3" cellpadding=...
#
#                                             article_text  \
# 10900  New Delhi [India], Dec 20 (ANI): A financing a...
# 4268   Development projects worth more than Rs 40,000...
# 1663   Ten Lessons\n\nDevelopment with Chinese Charac...
# 3789   Minister of Industry, Commerce, Agriculture an...
# 6657   The Asian Development Bank's (ADB) Board of Di...
#
#                                         article_keywords  article_text_len  \
# 10900  [institutes, india, skill, financing, training...              1031
# 4268   [development, crore, andhra, eaps, state, proj...              4390
# 1663   [transitions, university, chinese, united, dev...               575
# 3789   [research, development, agriculture, fisheries...              2621
# 6657   [highways, improvement, india, state, upgrade,...              2532
#
#       top_lang
# 10900       en
# 4268        en
# 1663        en
# 3789        en
# 6657        en

# %%
news_data.article_text = news_data.article_text.apply(lambda x: x.replace('\n', ''))

# %%
news_data['article_text_nlp'] = news_data.article_text.apply(nlp)

# %%
news_data['article_text_entities'] = news_data.article_text_nlp.apply(lambda x: x.ents)

# %%
def length_of(description):
    if type(description) != str:
        return 0
    else:
        return len(description.split(' '))

# %% [markdown]
# # When you want to Test your algorithm

# %% [markdown]
# * The projects in the labeled data should also present in the projects data.
# * WATCH OUT : Some articles are linked to multiple projects so you need to decide on how to deal with before you just join the files
# * ALSO : The labeled data inlcudes articles that don't match projects (Articles that should be classified as having NO Match) - you can see this if the "Matched" field = 0.

# %%
projects_labeled.columns
# Out:
# Index(['article_id', 'published', 'title', 'url', 'feed_label',
#        'ProjectNumber', 'EWS Project Name', 'EWS hyperlink', 'Matched'],
#       dtype='object')

# %%
news_data.columns
# Out:
# Index(['article_id', 'title', 'url', 'feed_label', 'content', 'published',
#        'summary', 'article_text', 'article_keywords', 'article_text_len',
#        'top_lang'],
#       dtype='object')

# %%
project_info.columns
# Out:
# Index(['EWS ID', 'ProjectNumber', 'Published', 'Bank Risk Rating',
#        'Project Status', 'EWS URL', 'Detailed Analysis URL', 'Project Name',
#        'City', 'Country Count', 'Country 1', 'Country 2', 'Country 3',
#        'Country 4', 'Country 5', 'Country 6', 'Country 7', 'Country 8',
#        'Country 9', 'Country 10', 'Country 11', 'Country 12',
#        'Borrower or Client', 'Private Actor Count', 'Private Actor 1',
#        'Private Actor 2', 'Private Actor 3', 'Private Actor 4',
#        'Private Actor 5', 'Private Actor 6', 'Private Actor 7',
#        'Private Actor 8', 'Private Actor 9', 'Private Actor 10',
#        'Private Actor 11', 'Private Actor 12', 'Private Actor 13',
#        'Private Actor 14', 'Private Actor 15', 'Bank Count', 'Bank 1',
#        'Bank 2', 'Bank 3', 'Bank 4', 'Bank 5', 'Sector Count', 'Sector 1',
#        'Sector 2', 'Sector 3', 'Sector 4', 'Sector 5', 'Sector 6', 'Sector 7',
#        'Last Edited', 'Date Scraped', 'Date Disclosed', 'Board Date',
#        'Source URL', 'Project Cost', 'Investment Amount',
#        'Project Description', 'Contact Information'],
#       dtype='object')

# %%
project_info_snip = project_info[['ProjectNumber', 'Project Description', 'Project Name']].copy()
project_info_snip['Project Description'] = project_info_snip['Project Description'].astype('str')
project_info_snip['Project Name'] = project_info_snip['Project Name'].astype('str')
project_info_snip['Project Description'] = project_info_snip['Project Description'].apply(lambda x: x.replace('\n', ''))

news_data_snip = news_data[['article_id', 'article_text', 'article_keywords', 'title']].copy()
news_data_snip.article_text = news_data_snip.article_text.apply(lambda x: x.replace('\n', ''))
news_data_snip.rename(columns={'title':'article_title'}, inplace=True)

projects_labeled_snip = projects_labeled[['article_id', 'ProjectNumber', 'Matched']].copy()
projects_labeled_snip['ProjectNumber'] = projects_labeled_snip['ProjectNumber'].astype(str)
#projects_labeled_snip = projects_labeled_snip.dropna()

# %%
## Explode rows with multiple project numbers
x = projects_labeled_snip.assign(**{'ProjectNumber':projects_labeled_snip['ProjectNumber'].str.split(',')})
projects_labeled_snip_explode = pd.DataFrame({col:np.repeat(x[col].values, x['ProjectNumber'].str.len())
                                              for col in x.columns.difference(['ProjectNumber'])}).assign(**{'ProjectNumber':np.concatenate(x['ProjectNumber'].values)})[x.columns.tolist()]

# %%
train_df = projects_labeled_snip_explode.merge(news_data_snip, on='article_id', how='inner')

# %%
train_df = train_df.merge(project_info_snip, on='ProjectNumber', how='outer')
train_df = train_df[train_df.Matched.isin([0,1])]
train_df['Matched'] = train_df['Matched'].astype(int)

# %%
#train_df.to_csv('../Data/train_df_clean.csv')

# %%
train_df.columns
# Out:
# Index(['article_id', 'ProjectNumber', 'Matched', 'article_text',
#        'article_keywords', 'article_title', 'Project Description',
#        'Project Name'],
#       dtype='object')

# %%
nlp = spacy.load('en_core_web_lg')

# %%
train_df.loc[train_df['Project Description'].apply(type) != str]
# Out:
# Empty DataFrame
# Columns: [article_id, ProjectNumber, Matched, article_text, article_keywords, article_title, Project Description, Project Name]
# Index: []

# %%
train_df['Project Description'] = train_df['Project Description'].astype('str')

# %%
train_df.loc[train_df['Project Name'].apply(type) != str]
# Out:
# Empty DataFrame
# Columns: [article_id, ProjectNumber, Matched, article_text, article_keywords, article_title, Project Description, Project Name]
# Index: []

# %%
train_df['Project Name'] = train_df['Project Name'].astype('str')

# %%
def apply_nlp_col(df, col_name, nlp_model):
    df['{}_nlp'.format(col_name)] = df[col_name].apply(lambda x: nlp_model(x))
    return df

# %%
train_df = apply_nlp_col(train_df, 'article_title', nlp)
train_df = apply_nlp_col(train_df, 'article_text', nlp)

train_df = apply_nlp_col(train_df, 'Project Description', nlp)
train_df = apply_nlp_col(train_df, 'Project Name', nlp)

# %%
train_df.columns
# Out:
# Index(['article_id', 'ProjectNumber', 'Matched', 'article_text',
#        'article_keywords', 'article_title', 'Project Description',
#        'Project Name', 'article_title_nlp', 'article_text_nlp',
#        'Project Description_nlp', 'Project Name_nlp'],
#       dtype='object')

# %%
def apply_entity_col(df, col_name):
    df['{}_entities'.format(col_name)] = df['{}_nlp'.format(col_name)].apply(lambda x: x.ents)
    return df

# %%
train_df = apply_entity_col(train_df, 'article_title')
train_df = apply_entity_col(train_df, 'article_text')

train_df = apply_entity_col(train_df, 'Project Description')
train_df = apply_entity_col(train_df, 'Project Name')

# %%
train_df.columns
# Out:
# Index(['article_id', 'ProjectNumber', 'Matched', 'article_text',
#        'article_keywords', 'article_title', 'Project Description',
#        'Project Name', 'article_title_nlp', 'article_text_nlp',
#        'Project Description_nlp', 'Project Name_nlp', 'article_title_entities',
#        'article_text_entities', 'Project Description_entities',
#        'Project Name_entities'],
#       dtype='object')

# %%
train_df
# Out:
#    article_id  ProjectNumber  Matched  \
# 0     10f9ed2  ADB-41123-015        1
# 1    c0eece9b  ADB-47282-001        1
# 2    d1d79dd8  ADB-50312-003        1
# 3    21b9419d  ADB-50312-003        1
# 4     f0d65e5  ADB-50410-001        1
# 5    4a557358  ADB-50410-001        1
# 6    817a9fee  ADB-50410-001        1
# 7    1d18e02b  ADB-50410-001        1
# 8    5ae8d202  ADB-50410-001        1
# 9    e9482ff2  ADB-50410-001        1
# 10   6c25cda0    AIIB-000011        1
# 11     f08d78    AIIB-000015        1
# 12   21bcdf5b    AIIB-000015        1
# 13    cb7b1ba    AIIB-000015        1
# 14   d71af9e4    AIIB-000015        1
# 15   ed93f7da    AIIB-000015        1
# 16   def9e94e    AIIB-000019        1
# 17   b37f386d    AIIB-000020        1
# 18   7d30b559    AIIB-000020        1
# 19   53b2c218    AIIB-000021        1
# 20   9917d30a    AIIB-000023        1
# 21   8d7610c9    AIIB-000038        1
# 22   e447cff1    AIIB-000038        1
# 23   328b7a21    AIIB-000079        1
# 24   9b695369    AIIB-000079        1
# 25   67ebc632      AIIB-0003        1
# 26   8eba7336     AIIB-00057        1
# 27   1d0142a4     AIIB-00057        1
# 28   11a35f15     AIIB-00057        1
# 29   961f2ed8     AIIB-00057        1
# ..        ...            ...      ...
# 56   16482ff0   EIB-20150676        1
# 57   a8a842c4   EIB-20150676        1
# 58   53a92bf8   EIB-20150676        1
# 59   b1310eb5   EIB-20160341        1
# 60   af79244f   EIB-20160727        1
# 61   ef0ef031   EIB-20160816        1
# 62   e819156c   EIB-20161001        1
# 63   cf5a35d4   EIB-20161001        1
# 64   1e153953   EIB-20170105        1
# 65   62e12c0d   EIB-20170819        1
# 66   9206496f     EBRD-48424        1
# 67    4827d3f      GCF-FP080        1
# 68   96b5109d  IADB-EC-L1111        1
# 69   9bbee377  IADB-EC-L1111        1
# 70   73334df7   IIC-12063-02        1
# 71   f22acccb   IIC-12063-02        1
# 72   2d23370d   IIC-12116-01        1
# 73   c5346537  ADB-36330-033        1
# 74   8c34b030     WB-P146330        1
# 75   44e02446     WB-P148775        1
# 76   e982195d     WB-P160408        1
# 77   5a307c9e     WB-P161234        1
# 78   21044d5f     WB-P162422        1
# 79   340d79e8     WB-P163628        1
# 80   cf03c965   EIB-20170635        1
# 81   c4d39fcc   EIB-20160848        1
# 82   b8dd4c57  ADB-47320-001        1
# 83   38d2206c   IIC-11794-04        1
# 84   925ca007   IIC-12114-01        1
# 85   8cfcf435   IIC-12161-01        1
#
#                                          article_text  \
# 0   The Asian Development Bank (ADB) today signed ...
# 1   KABUL, AFGHANISTAN (14 May 2018) — The Asian D...
# 2   MANILA, PHILIPPINES (21 February 2018) — The B...
# 3   The Board of Directors of the Asian Developmen...
# 4   //es_subbox( $namefield = " ", $desc = "Subscr...
# 5   The Asian Development Bank (ADB) has agreed to...
# 6   B.Grimm Power secures ADB loan to support rene...
# 7   Compelo is using cookiesWe use them to give yo...
# 8   BANGKOK, THAILAND (23 February 2018) — The Asi...
# 9   United Nations Deputy Secretary-General Amina ...
# 10  By TrendAsian Infrastructure Investment Bank (...
# 11  AIIB Head of Communications and Development La...
# 12  DHAKA, Feb 26 (Reuters) - Beijing-based Asian ...
# 13  DHAKA (Reuters) - Beijing-based Asian Infrastr...
# 14  Beijing-based Asian Infrastructure Investment ...
# 15  PremiumBeijing-based Asian Infrastructure Inve...
# 16  By Our RepresentativePassed in order to "exped...
# 17  AIIB to invest $140mn to perk up rural roads i...
# 18  Asian Infrastructure Investment Bank (AIIB) wo...
# 19  For years, Beijing has cast a shadow on a patc...
# 20  MANILA - A $500-million flood control project ...
# 21  BENGALURU: The Bangalore Metro Rail Corporatio...
# 22  BENGALURU: The European Investment Bank (EIB) ...
# 23  Guntur: In what could be a big relief from wat...
# 24  By Express News ServiceVIJAYAWADA: For the exe...
# 25  DHAKA (Reuters) - Beijing-based Asian Infrastr...
# 26  Country * Please Select Afghanistan Åland Isla...
# 27  DHAKA, Feb. 26 (Xinhua) -- The Asian Infrastru...
# 28  The Beijing-based Asian Infrastructure Investm...
# 29  The Asian Infrastructure Investment Bank (AIIB...
# ..                                                ...
# 56  TAP Gas Pipeline To Get 1.2B Euros In Loans Fr...
# 57  Baku, Azerbaijan, Feb.20By Leman Zeynalova – T...
# 58  BAKU, Feb 20 (Reuters) - The European Bank for...
# 59  EIB to lend 130 mln euro for Serbia's Nis-Dimi...
# 60  Share this: FacebookTwitterGoogleLinkedInReddi...
# 61  On Tuesday, BMRCL MD Mahendra Jain signed a pr...
# 62  The European Investment Bank (EIB) has provide...
# 63  The European Investment Bank (EIB) has provide...
# 64  New Delhi, Mar 10 (PTI) Indian Renewable Energ...
# 65  Valmet Oyj of Finland has signed a Euro 45 mil...
# 66  The European Bank for Reconstruction and Devel...
# 67  WorldStage Newsonline– Nigeria’s President Muh...
# 68  Close Methodology & ProceduresDefinitionsProje...
# 69  The Inter-American Development Bank (IDB) has ...
# 70  IDB Invest and IFC are providing 15-year debt ...
# 71  IDB finances 48-MW wind park in ArgentinaApril...
# 72  IDB Invest, the private sector institution of ...
# 73  The FINANCIAL -- The Asian Development Bank (A...
# 74  The World Bank (WB) has agreed to provide $486...
# 75  The signing of the Agreement follows the appro...
# 76  The Government of India, Government of Maharas...
# 77  Today, the World Bank approved additional fina...
# 78  NAIROBI, April 30 (Reuters) - The World Bank a...
# 79  General News of Tuesday, 13 February 2018Sourc...
# 80  The company – 60% owned by Helios Investment P...
# 81  The European Investment Bank (EIB) has announc...
# 82  APIA, SAMOA (9 February 2018) — The Asian Deve...
# 83  Inter-American Development Bank’s (IDB) privat...
# 84  Banco Davivienda, a leader in financing for Co...
# 85  IDB Invest, the private sector institution of ...
#
#                                      article_keywords  \
# 0   [development, supply, tonle, million, infrastr...
# 1   [helps, network, development, electricity, sou...
# 2   [boost, freight, railway, rolling, transport, ...
# 3   [development, railway, approves, rolling, oper...
# 4   [bgrimm, support, expansion, southeast, renewa...
# 5   [asean, region, adbs, bgrimm, support, expansi...
# 6   [asean, bgrimm, sector, support, operating, re...
# 7   [continue, using, experience, website, archive...
# 8   [asean, bgrimm, sector, support, operating, re...
# 9   [asean, bgrimm, region, development, support, ...
# 10  [strengthen, aiib, opening, coop, infrastructu...
# 11  [considering, release, invest, projects, 885m,...
# 12  [loans, aiib, viable, million, approves, power...
# 13  [development, ostfield, approves, projects, mi...
# 14  [development, ostfield, approves, projects, mi...
# 15  [senior, projects, million, bangladesh, power,...
# 16  [build, system, acquisition, passed, scheme, c...
# 17  [aiib, invest, women, connectivity, state, imp...
# 18  [pradeshs, aiib, mn, release, million, improve...
# 19  [georgia, chinese, economic, road, free, port,...
# 20  [flood, million, vulnerable, tuesdayphase, wor...
# 21  [nagawara, work, tunnel, rs, line, dairy, rout...
# 22  [sign, line, european, pact, funding, signed, ...
# 23  [guntur, comprehensive, state, drinking, munic...
# 24  [sanction, aiib, supply, accords, state, andhr...
# 25  [aiib, development, waythese, approves, millio...
# 26  [aiib, states, south, approves, island, saint,...
# 27  [aiib, approves, mln, bhola, 60, ipp, infrastr...
# 28  [aiib, development, approves, million, 60mn, i...
# 29  [reduce, ipp, increase, bhola, loan, help, pro...
# ..                                                ...
# 56  [ebrd, pipeline, gas, european, 2018, expected...
# 57  [euros, gas, tap, ready, financing, 20, worth,...
# 58  [euros, gas, expected, bln, tap, 12, european,...
# 59  [railway, scannapieco, serbia, mln, serbias, m...
# 60  [eu, european, begins, borissov, euro, plan, a...
# 61  [nagawara, signs, financial, line, gottigere, ...
# 62  [kits, offgrid, sustainable, company, 25m, eib...
# 63  [offgrid, powers, funding, company, million, s...
# 64  [ink, today, credit, line, ireda, million, 150...
# 65  [lower, finland, operational, signs, european,...
# 66  [ebrd, figeac, tunisia, lends, expansion, seme...
# 67  [past, president, nigerias, shifted, worldstag...
# 68  [taken, original, metro, loan, changes, estima...
# 69  [system, latin, line, building, mln, quito, mi...
# 70  [invest, finance, million, transmission, fund,...
# 71  [sector, wind, 48mw, finances, invest, park, p...
# 72  [edition, mn, usd, financial, services, invest...
# 73  [program, 120, railway, yokoyama, million, imp...
# 74  [network, sector, 486m, nigeria, transmission,...
# 75  [navigation, jal, varanasi, ganga, india, wate...
# 76  [water, agriculture, india, climate, 420, fund...
# 77  [boost, development, growth, million, private,...
# 78  [electricity, guarantee, mln, kenyas, world, k...
# 79  [school, working, support, 40m, policy, secure...
# 80  , telkom, million, fund, kenya, orange, in...
# 81  [peru, development, european, stated, wind, pr...
# 82  [goes, australiasupported, submarine, world, m...
# 83  [provided, commercial, investadministered, col...
# 84  [housing, development, financing, information,...
# 85  [helps, companies, midsized, global, invest, f...
#
#                                         article_title  \
# 0   ADB Provides Support for Three Infrastructure ...
# 1   ADB Helps Inaugurate New Power Distribution Ne...
# 2   ADB Provides $360 Million for Rolling Stock to...
# 3    ADB approves $360 m loan for railway development
# 4   ADB provides financing to Thailand's B.Grimm P...
# 5   ADB's $235m loan to support B.Grimm Power expa...
# 6   B.Grimm Power secures ADB loan to support rene...
# 7   B.Grimm Power secures ADB loan for ASEAN renew...
# 8   ADB, B.Grimm Power Expand Support for Renewabl...
# 9   ADB, B.Grimm Power Expand Support for Renewabl...
# 10     AIIB seeks to strengthen co-op with Azerbaijan
# 11  AIIB approves $60 million for Bangladesh power...
# 12  AIIB approves $285 million of loans to Banglad...
# 13  AIIB approves $285 million of loans to Banglad...
# 14  AIIB approves $285m of loans to Bangladesh for...
# 15  AIIB approves $285m in loans to Bangladesh for...
# 16  Andhra land acquisition law passed under World...
# 17  AIIB to invest $140mn to perk up rural roads i...
# 18  AIIB grants $140 mn loan to improve Madhya Pra...
# 19  With Port Project, Georgia Seeks Place on Chin...
# 20  Metro Manila flood control project may start i...
# 21  BMRCL may tweak packages, tunnel length on Dai...
# 22  European investment bank & BMRCL sign project ...
# 23  10 towns in Krishna, Guntur to get new water s...
# 24  Andhra Pradesh government accords sanction for...
# 25  AIIB approves $285 million of loans to Banglad...
# 26  AIIB approves loan to Bangladesh Independent P...
# 27  AIIB approves 60 mln USD loan for Bangladesh p...
# 28  AIIB approves $60mn loan for Bangladesh power ...
# 29  AIIB approves loan for Bangladesh Bhola IPP en...
# ..                                                ...
# 56  TAP Gas Pipeline To Get 1.2B Euros In Loans Fr...
# 57        EBRD to allocate 1.2B euros for TAP in 2018
# 58  TAP gas pipeline to get 1.2 bln euros in loans...
# 59  EIB to lend 130 mln euro for Serbia's Nis-Dimi...
# 60  Bulgarian EU Presidency begins with EIB loan o...
# 61             BMRCL signs project agreement with EIB
# 62         EIB pumps $25m into off-grid solar project
# 63  EIB powers African solar firm d.light with US$...
# 64  IREDA, EIB ink 150mn-euro loan agreement for r...
# 65  Valmet signs Euro 45 million loan agreement wi...
# 66  EBRD Lends Figeac Aéro €38 Mln for Expansion i...
# 67  AfDB obtains $52.5m Green Climate Fund for Zam...
# 68          IDB approves another loan for Quito metro
# 69  IDB approves USD 250 mln loan to help build a ...
# 70  IDB Invest, IFC finance Achiras wind farm in A...
# 71          IDB finances 48-MW wind park in Argentina
# 72  IDB invests USD 5 mn in MONI Online in its fir...
# 73  ADB, India Sign $120 Million Loan to Improve R...
# 74  World Bank approves $486m to improve Nigeria's...
# 75  Inland Waterways Authority Of India Signs Proj...
# 76  World Bank to fund $ 420 mn for climate resili...
# 77  Burkina Faso: World Bank Approves $50 Million ...
# 78  World Bank approves $180 mln loan guarantee fo...
# 79  Government secures $40m from World Bank to sup...
# 80  Telkom Kenya applies for EIB loan to help fund...
# 81  European Investment Bank provides $150m for re...
# 82  ADB, World Bank, Australia-Supported High-Spee...
# 83  IDB to provide $1bn loan for 2.4GW hydropower ...
# 84  Inter-American Development Bank Loans Davivien...
# 85  IDB helps Brazil to expand access to financing...
#
#                                   Project Description  \
# 0   The project aims to provide efficient transpor...
# 1   The MFF will reinforce ongoing projects and fi...
# 2   The Government of Bangladesh proposed a projec...
# 3   The Government of Bangladesh proposed a projec...
# 4   ADB's equity investment and corporate loan fac...
# 5   ADB's equity investment and corporate loan fac...
# 6   ADB's equity investment and corporate loan fac...
# 7   ADB's equity investment and corporate loan fac...
# 8   ADB's equity investment and corporate loan fac...
# 9   ADB's equity investment and corporate loan fac...
# 10  This project finances the Trans-Anatolian Natu...
# 11  According to AIIB documents, "the objectives o...
# 12  According to AIIB documents, "the objectives o...
# 13  According to AIIB documents, "the objectives o...
# 14  According to AIIB documents, "the objectives o...
# 15  According to AIIB documents, "the objectives o...
# 16  The stated development objective of the Projec...
# 17  According to AIIB documents, the objective of ...
# 18  According to AIIB documents, the objective of ...
# 19  According to AIIB documents, this project will...
# 20  According to AIIB website: "the Project object...
# 21  According to AIIB documents, the project will ...
# 22  According to AIIB documents, the project will ...
# 23  To improve water supply and sanitation service...
# 24  To improve water supply and sanitation service...
# 25  AIIB approved a loan of $165 million for the D...
# 26  The Asian Infrastructure Investment Bank (AIIB...
# 27  The Asian Infrastructure Investment Bank (AIIB...
# 28  The Asian Infrastructure Investment Bank (AIIB...
# 29  The Asian Infrastructure Investment Bank (AIIB...
# ..                                                ...
# 56  This project will finance the construction of ...
# 57  This project will finance the construction of ...
# 58  This project will finance the construction of ...
# 59  This project finances the modernization and re...
# 60  This project finances the construction of new ...
# 61  This project involves the construction of a 23...
# 62  The project consists of the design, assembling...
# 63  The project consists of the design, assembling...
# 64  This project finances a framework loan to fina...
# 65  This project finances investments in Valmet Oy...
# 66  This project provides long-term financing to F...
# 67  The Government of the Republic of Zambia (GRZ)...
# 68  The Program will finance the construction of 2...
# 69  The Program will finance the construction of 2...
# 70  The Achiras Wind Power Project consists of the...
# 71  The Achiras Wind Power Project consists of the...
# 72  Moni is a provider of financial services and a...
# 73  This project funds buying an additional 840 ki...
# 74                                                nan
# 75  This project provides financing to improve eff...
# 76  The project has the stated objective of enhanc...
# 77                                                nan
# 78                                                nan
# 79  The development objective of the Secondary Edu...
# 80  According to EIB website, the project aims to ...
# 81  The EIB is considering financing of the invest...
# 82  According to ADB documents, the project will s...
# 83  El banco financiara a Empresas Publicas de Med...
# 84  This Project aims to support the increase in m...
# 85  Bozano Investimentos Growth Capital Fund I, L....
#
#                                          Project Name  \
# 0   Road Network Improvement Project (formerly Sec...
# 1       Energy Supply Improvement Investment Program
# 2   Railway Rolling Stock Operations Improvement P...
# 3   Railway Rolling Stock Operations Improvement P...
# 4   ASEAN Distributed Power Project: Initial Pover...
# 5   ASEAN Distributed Power Project: Initial Pover...
# 6   ASEAN Distributed Power Project: Initial Pover...
# 7   ASEAN Distributed Power Project: Initial Pover...
# 8   ASEAN Distributed Power Project: Initial Pover...
# 9   ASEAN Distributed Power Project: Initial Pover...
# 10  Azerbaijan: Trans Anatolian Natural Gas Pipeli...
# 11  Bangladesh: Natural Gas Infrastructure and Eff...
# 12  Bangladesh: Natural Gas Infrastructure and Eff...
# 13  Bangladesh: Natural Gas Infrastructure and Eff...
# 14  Bangladesh: Natural Gas Infrastructure and Eff...
# 15  Bangladesh: Natural Gas Infrastructure and Eff...
# 16  India: Amaravati Sustainable Capital City Deve...
# 17   India: Madhya Pradesh Rural Connectivity Project
# 18   India: Madhya Pradesh Rural Connectivity Project
# 19                Georgia: Batumi Bypass Road Project
# 20  Philippines: Metro Manila Flood Management Pro...
# 21      India: Bangalore Metro Rail Project - Line R6
# 22      India: Bangalore Metro Rail Project - Line R6
# 23  India: Andhra Pradesh Urban Water Supply and S...
# 24  India: Andhra Pradesh Urban Water Supply and S...
# 25  Bangladesh: Distribution System Upgrade and Ex...
# 26                               Bangladesh Bhola IPP
# 27                               Bangladesh Bhola IPP
# 28                               Bangladesh Bhola IPP
# 29                               Bangladesh Bhola IPP
# ..                                                ...
# 56         TANAP TRANS-ANATOLIAN NATURAL GAS PIPELINE
# 57         TANAP TRANS-ANATOLIAN NATURAL GAS PIPELINE
# 58         TANAP TRANS-ANATOLIAN NATURAL GAS PIPELINE
# 59                           RAILWAY NIS-DIMITROVGRAD
# 60                                    BIOVET PESHTERA
# 61         Bangalore Metro Rail Corporation - LINE R6
# 62                        OFF-GRID SOLAR ACCELERATION
# 63                        OFF-GRID SOLAR ACCELERATION
# 64   IREDA-RENEWABLE ENERGY AND ENERGY EFFICIENCY FL2
# 65                            VALMET - AUTOMATION RDI
# 66                               Figeac Aero Regional
# 67       Zambia Renewable Energy Investment Framework
# 68          Quito Metropolitan Urban Transport System
# 69          Quito Metropolitan Urban Transport System
# 70                         Achiras Wind Power Project
# 71                         Achiras Wind Power Project
# 72                                   Moni Online S.A.
# 73      Railway Sector Investment Program - Tranche 2
# 74                NG-Electricity Transmission Project
# 75  Capacity Augmentation of the National Waterway...
# 76                                                nan
# 77  Burkina Faso - Bagre Growth Pole Project Addit...
# 78                           KenGen Guarantee Program
# 79  Secondary Education Improvement Project Additi...
# 80                            KENYA TELECOM EXPANSION
# 81                              ENEL GREEN POWER PERU
# 82                      Samoa Submarine Cable Project
# 83                      Planta Hidroelectrica Ituango
# 84                                Davivienda Colombia
# 85                         Bozano Growth Capital Fund
#
#                                     article_title_nlp  \
# 0   (ADB, Provides, Support, for, Three, Infrastru...
# 1   (ADB, Helps, Inaugurate, New, Power, Distribut...
# 2   (ADB, Provides, $, 360, Million, for, Rolling,...
# 3   (ADB, approves, $, 360, m, loan, for, railway,...
# 4   (ADB, provides, financing, to, Thailand, 's, B...
# 5   (ADB, 's, $, 235, m, loan, to, support, B.Grim...
# 6   (B.Grimm, Power, secures, ADB, loan, to, suppo...
# 7   (B.Grimm, Power, secures, ADB, loan, for, ASEA...
# 8   (ADB, ,, B.Grimm, Power, Expand, Support, for,...
# 9   (ADB, ,, B.Grimm, Power, Expand, Support, for,...
# 10  (AIIB, seeks, to, strengthen, co, -, op, with,...
# 11  (AIIB, approves, $, 60, million, for, Banglade...
# 12  (AIIB, approves, $, 285, million, of, loans, t...
# 13  (AIIB, approves, $, 285, million, of, loans, t...
# 14  (AIIB, approves, $, 285, m, of, loans, to, Ban...
# 15  (AIIB, approves, $, 285, m, in, loans, to, Ban...
# 16  (Andhra, land, acquisition, law, passed, under...
# 17  (AIIB, to, invest, $, 140mn, to, perk, up, rur...
# 18  (AIIB, grants, $, 140, mn, loan, to, improve, ...
# 19  (With, Port, Project, ,, Georgia, Seeks, Place...
# 20  (Metro, Manila, flood, control, project, may, ...
# 21  (BMRCL, may, tweak, packages, ,, tunnel, lengt...
# 22  (European, investment, bank, &, BMRCL, sign, p...
# 23  (10, towns, in, Krishna, ,, Guntur, to, get, n...
# 24  (Andhra, Pradesh, government, accords, sanctio...
# 25  (AIIB, approves, $, 285, million, of, loans, t...
# 26  (AIIB, approves, loan, to, Bangladesh, Indepen...
# 27  (AIIB, approves, 60, mln, USD, loan, for, Bang...
# 28  (AIIB, approves, $, 60mn, loan, for, Banglades...
# 29  (AIIB, approves, loan, for, Bangladesh, Bhola,...
# ..                                                ...
# 56  (TAP, Gas, Pipeline, To, Get, 1.2B, Euros, In,...
# 57  (EBRD, to, allocate, 1.2B, euros, for, TAP, in...
# 58  (TAP, gas, pipeline, to, get, 1.2, bln, euros,...
# 59  (EIB, to, lend, 130, mln, euro, for, Serbia, '...
# 60  (Bulgarian, EU, Presidency, begins, with, EIB,...
# 61      (BMRCL, signs, project, agreement, with, EIB)
# 62  (EIB, pumps, $, 25, m, into, off, -, grid, sol...
# 63  (EIB, powers, African, solar, firm, d.light, w...
# 64  (IREDA, ,, EIB, ink, 150mn, -, euro, loan, agr...
# 65  (Valmet, signs, Euro, 45, million, loan, agree...
# 66  (EBRD, Lends, Figeac, Aéro, €, 38, Mln, for, E...
# 67  (AfDB, obtains, $, 52.5, m, Green, Climate, Fu...
# 68  (IDB, approves, another, loan, for, Quito, metro)
# 69  (IDB, approves, USD, 250, mln, loan, to, help,...
# 70  (IDB, Invest, ,, IFC, finance, Achiras, wind, ...
# 71  (IDB, finances, 48-MW, wind, park, in, Argentina)
# 72  (IDB, invests, USD, 5, mn, in, MONI, Online, i...
# 73  (ADB, ,, India, Sign, $, 120, Million, Loan, t...
# 74  (World, Bank, approves, $, 486, m, to, improve...
# 75  (Inland, Waterways, Authority, Of, India, Sign...
# 76  (World, Bank, to, fund, $, 420, mn, for, clima...
# 77  (Burkina, Faso, :, World, Bank, Approves, $, 5...
# 78  (World, Bank, approves, $, 180, mln, loan, gua...
# 79  (Government, secures, $, 40, m, from, World, B...
# 80  (Telkom, Kenya, applies, for, EIB, loan, to, h...
# 81  (European, Investment, Bank, provides, $, 150,...
# 82  (ADB, ,, World, Bank, ,, Australia, -, Support...
# 83  (IDB, to, provide, $, 1bn, loan, for, 2.4GW, h...
# 84  (Inter, -, American, Development, Bank, Loans,...
# 85  (IDB, helps, Brazil, to, expand, access, to, f...
#
#                                      article_text_nlp  \
# 0   (The, Asian, Development, Bank, (, ADB, ), tod...
# 1   (KABUL, ,, AFGHANISTAN, (, 14, May, 2018, ), —...
# 2   (MANILA, ,, PHILIPPINES, (, 21, February, 2018...
# 3   (The, Board, of, Directors, of, the, Asian, De...
# 4   (//es_subbox, (, $, namefield, =, ", ", ,, $, ...
# 5   (The, Asian, Development, Bank, (, ADB, ), has...
# 6   (B.Grimm, Power, secures, ADB, loan, to, suppo...
# 7   (Compelo, is, using, cookiesWe, use, them, to,...
# 8   (BANGKOK, ,, THAILAND, (, 23, February, 2018, ...
# 9   (United, Nations, Deputy, Secretary, -, Genera...
# 10  (By, TrendAsian, Infrastructure, Investment, B...
# 11  (AIIB, Head, of, Communications, and, Developm...
# 12  (DHAKA, ,, Feb, 26, (, Reuters, ), -, Beijing,...
# 13  (DHAKA, (, Reuters, ), -, Beijing, -, based, A...
# 14  (Beijing, -, based, Asian, Infrastructure, Inv...
# 15  (PremiumBeijing, -, based, Asian, Infrastructu...
# 16  (By, Our, RepresentativePassed, in, order, to,...
# 17  (AIIB, to, invest, $, 140mn, to, perk, up, rur...
# 18  (Asian, Infrastructure, Investment, Bank, (, A...
# 19  (For, years, ,, Beijing, has, cast, a, shadow,...
# 20  (MANILA, -, A, $, 500-million, flood, control,...
# 21  (BENGALURU, :, The, Bangalore, Metro, Rail, Co...
# 22  (BENGALURU, :, The, European, Investment, Bank...
# 23  (Guntur, :, In, what, could, be, a, big, relie...
# 24  (By, Express, News, ServiceVIJAYAWADA, :, For,...
# 25  (DHAKA, (, Reuters, ), -, Beijing, -, based, A...
# 26  (Country, *, Please, Select, Afghanistan, Ålan...
# 27  (DHAKA, ,, Feb., 26, (, Xinhua, ), --, The, As...
# 28  (The, Beijing, -, based, Asian, Infrastructure...
# 29  (The, Asian, Infrastructure, Investment, Bank,...
# ..                                                ...
# 56  (TAP, Gas, Pipeline, To, Get, 1.2B, Euros, In,...
# 57  (Baku, ,, Azerbaijan, ,, Feb.20By, Leman, Zeyn...
# 58  (BAKU, ,, Feb, 20, (, Reuters, ), -, The, Euro...
# 59  (EIB, to, lend, 130, mln, euro, for, Serbia, '...
# 60  (Share, this, :, FacebookTwitterGoogleLinkedIn...
# 61  (On, Tuesday, ,, BMRCL, MD, Mahendra, Jain, si...
# 62  (The, European, Investment, Bank, (, EIB, ), h...
# 63  (The, European, Investment, Bank, (, EIB, ), h...
# 64  (New, Delhi, ,, Mar, 10, (, PTI, ), Indian, Re...
# 65  (Valmet, Oyj, of, Finland, has, signed, a, Eur...
# 66  (The, European, Bank, for, Reconstruction, and...
# 67  (WorldStage, Newsonline–, Nigeria, ’s, Preside...
# 68  (Close, Methodology, &, ProceduresDefinitionsP...
# 69  (The, Inter, -, American, Development, Bank, (...
# 70  (IDB, Invest, and, IFC, are, providing, 15-yea...
# 71  (IDB, finances, 48-MW, wind, park, in, Argenti...
# 72  (IDB, Invest, ,, the, private, sector, institu...
# 73  (The, FINANCIAL, --, The, Asian, Development, ...
# 74  (The, World, Bank, (, WB, ), has, agreed, to, ...
# 75  (The, signing, of, the, Agreement, follows, th...
# 76  (The, Government, of, India, ,, Government, of...
# 77  (Today, ,, the, World, Bank, approved, additio...
# 78  (NAIROBI, ,, April, 30, (, Reuters, ), -, The,...
# 79  (General, News, of, Tuesday, ,, 13, February, ...
# 80  (The, company, –, 60, %, owned, by, Helios, In...
# 81  (The, European, Investment, Bank, (, EIB, ), h...
# 82  (APIA, ,, SAMOA, (, 9, February, 2018, ), —, T...
# 83  (Inter, -, American, Development, Bank, ’s, (,...
# 84  (Banco, Davivienda, ,, a, leader, in, financin...
# 85  (IDB, Invest, ,, the, private, sector, institu...
#
#                               Project Description_nlp  \
# 0   (The, project, aims, to, provide, efficient, t...
# 1   (The, MFF, will, reinforce, ongoing, projects,...
# 2   (The, Government, of, Bangladesh, proposed, a,...
# 3   (The, Government, of, Bangladesh, proposed, a,...
# 4   (ADB, 's, equity, investment, and, corporate, ...
# 5   (ADB, 's, equity, investment, and, corporate, ...
# 6   (ADB, 's, equity, investment, and, corporate, ...
# 7   (ADB, 's, equity, investment, and, corporate, ...
# 8   (ADB, 's, equity, investment, and, corporate, ...
# 9   (ADB, 's, equity, investment, and, corporate, ...
# 10  (This, project, finances, the, Trans, -, Anato...
# 11  (According, to, AIIB, documents, ,, ", the, ob...
# 12  (According, to, AIIB, documents, ,, ", the, ob...
# 13  (According, to, AIIB, documents, ,, ", the, ob...
# 14  (According, to, AIIB, documents, ,, ", the, ob...
# 15  (According, to, AIIB, documents, ,, ", the, ob...
# 16  (The, stated, development, objective, of, the,...
# 17  (According, to, AIIB, documents, ,, the, objec...
# 18  (According, to, AIIB, documents, ,, the, objec...
# 19  (According, to, AIIB, documents, ,, this, proj...
# 20  (According, to, AIIB, website, :, ", the, Proj...
# 21  (According, to, AIIB, documents, ,, the, proje...
# 22  (According, to, AIIB, documents, ,, the, proje...
# 23  (To, improve, water, supply, and, sanitation, ...
# 24  (To, improve, water, supply, and, sanitation, ...
# 25  (AIIB, approved, a, loan, of, $, 165, million,...
# 26  (The, Asian, Infrastructure, Investment, Bank,...
# 27  (The, Asian, Infrastructure, Investment, Bank,...
# 28  (The, Asian, Infrastructure, Investment, Bank,...
# 29  (The, Asian, Infrastructure, Investment, Bank,...
# ..                                                ...
# 56  (This, project, will, finance, the, constructi...
# 57  (This, project, will, finance, the, constructi...
# 58  (This, project, will, finance, the, constructi...
# 59  (This, project, finances, the, modernization, ...
# 60  (This, project, finances, the, construction, o...
# 61  (This, project, involves, the, construction, o...
# 62  (The, project, consists, of, the, design, ,, a...
# 63  (The, project, consists, of, the, design, ,, a...
# 64  (This, project, finances, a, framework, loan, ...
# 65  (This, project, finances, investments, in, Val...
# 66  (This, project, provides, long, -, term, finan...
# 67  (The, Government, of, the, Republic, of, Zambi...
# 68  (The, Program, will, finance, the, constructio...
# 69  (The, Program, will, finance, the, constructio...
# 70  (The, Achiras, Wind, Power, Project, consists,...
# 71  (The, Achiras, Wind, Power, Project, consists,...
# 72  (Moni, is, a, provider, of, financial, service...
# 73  (This, project, funds, buying, an, additional,...
# 74                                              (nan)
# 75  (This, project, provides, financing, to, impro...
# 76  (The, project, has, the, stated, objective, of...
# 77                                              (nan)
# 78                                              (nan)
# 79  (The, development, objective, of, the, Seconda...
# 80  (According, to, EIB, website, ,, the, project,...
# 81  (The, EIB, is, considering, financing, of, the...
# 82  (According, to, ADB, documents, ,, the, projec...
# 83  (El, banco, financiara, a, Empresas, Publicas,...
# 84  (This, Project, aims, to, support, the, increa...
# 85  (Bozano, Investimentos, Growth, Capital, Fund,...
#
#                                      Project Name_nlp  \
# 0   (Road, Network, Improvement, Project, (, forme...
# 1   (Energy, Supply, Improvement, Investment, Prog...
# 2   (Railway, Rolling, Stock, Operations, Improvem...
# 3   (Railway, Rolling, Stock, Operations, Improvem...
# 4   (ASEAN, Distributed, Power, Project, :, Initia...
# 5   (ASEAN, Distributed, Power, Project, :, Initia...
# 6   (ASEAN, Distributed, Power, Project, :, Initia...
# 7   (ASEAN, Distributed, Power, Project, :, Initia...
# 8   (ASEAN, Distributed, Power, Project, :, Initia...
# 9   (ASEAN, Distributed, Power, Project, :, Initia...
# 10  (Azerbaijan, :, Trans, Anatolian, Natural, Gas...
# 11  (Bangladesh, :, Natural, Gas, Infrastructure, ...
# 12  (Bangladesh, :, Natural, Gas, Infrastructure, ...
# 13  (Bangladesh, :, Natural, Gas, Infrastructure, ...
# 14  (Bangladesh, :, Natural, Gas, Infrastructure, ...
# 15  (Bangladesh, :, Natural, Gas, Infrastructure, ...
# 16  (India, :, Amaravati, Sustainable, Capital, Ci...
# 17  (India, :, Madhya, Pradesh, Rural, Connectivit...
# 18  (India, :, Madhya, Pradesh, Rural, Connectivit...
# 19        (Georgia, :, Batumi, Bypass, Road, Project)
# 20  (Philippines, :, Metro, Manila, Flood, Managem...
# 21  (India, :, Bangalore, Metro, Rail, Project, -,...
# 22  (India, :, Bangalore, Metro, Rail, Project, -,...
# 23  (India, :, Andhra, Pradesh, Urban, Water, Supp...
# 24  (India, :, Andhra, Pradesh, Urban, Water, Supp...
# 25  (Bangladesh, :, Distribution, System, Upgrade,...
# 26                           (Bangladesh, Bhola, IPP)
# 27                           (Bangladesh, Bhola, IPP)
# 28                           (Bangladesh, Bhola, IPP)
# 29                           (Bangladesh, Bhola, IPP)
# ..                                                ...
# 56  (TANAP, TRANS, -, ANATOLIAN, NATURAL, GAS, PIP...
# 57  (TANAP, TRANS, -, ANATOLIAN, NATURAL, GAS, PIP...
# 58  (TANAP, TRANS, -, ANATOLIAN, NATURAL, GAS, PIP...
# 59                    (RAILWAY, NIS, -, DIMITROVGRAD)
# 60                                 (BIOVET, PESHTERA)
# 61  (Bangalore, Metro, Rail, Corporation, -, LINE,...
# 62                (OFF, -, GRID, SOLAR, ACCELERATION)
# 63                (OFF, -, GRID, SOLAR, ACCELERATION)
# 64  (IREDA, -, RENEWABLE, ENERGY, AND, ENERGY, EFF...
# 65                       (VALMET, -, AUTOMATION, RDI)
# 66                           (Figeac, Aero, Regional)
# 67  (Zambia, Renewable, Energy, Investment, Framew...
# 68    (Quito, Metropolitan, Urban, Transport, System)
# 69    (Quito, Metropolitan, Urban, Transport, System)
# 70                    (Achiras, Wind, Power, Project)
# 71                    (Achiras, Wind, Power, Project)
# 72                               (Moni, Online, S.A.)
# 73  (Railway, Sector, Investment, Program, -, Tran...
# 74        (NG, -, Electricity, Transmission, Project)
# 75  (Capacity, Augmentation, of, the, National, Wa...
# 76                                              (nan)
# 77  (Burkina, Faso, -, Bagre, Growth, Pole, Projec...
# 78                       (KenGen, Guarantee, Program)
# 79  (Secondary, Education, Improvement, Project, A...
# 80                        (KENYA, TELECOM, EXPANSION)
# 81                         (ENEL, GREEN, POWER, PERU)
# 82                 (Samoa, Submarine, Cable, Project)
# 83                  (Planta, Hidroelectrica, Ituango)
# 84                             (Davivienda, Colombia)
# 85                    (Bozano, Growth, Capital, Fund)
#
#                                article_title_entities  \
# 0     ((Three, Infrastructure, Projects), (Cambodia))
# 1                         ((ADB), (Southwest, Kabul))
# 2               (($, 360, Million), (Rolling, Stock))
# 3                                ((ADB), ($, 360, m))
# 4                                 ((ADB), (Thailand))
# 5                       ((ADB), ($, 235, m), (ASEAN))
# 6                  ((B.Grimm, Power), (ADB), (Asean))
# 7                  ((B.Grimm, Power), (ADB), (ASEAN))
# 8   ((ADB), (Power, Expand, Support, for, Renewabl...
# 9   ((ADB), (Power, Expand, Support, for, Renewabl...
# 10                             ((AIIB), (Azerbaijan))
# 11  ((AIIB), ($, 60, million), (Bangladesh), ($, 8...
# 12          ((AIIB), ($, 285, million), (Bangladesh))
# 13          ((AIIB), ($, 285, million), (Bangladesh))
# 14                ((AIIB), ($, 285, m), (Bangladesh))
# 15                ((AIIB), ($, 285, m), (Bangladesh))
# 16              ((Andhra), (World, Bank), (Amravati))
# 17               ((AIIB), (140mn), (Madhya, Pradesh))
# 18                     ((140), (Madhya, Pradesh, 's))
# 19  ((Port, Project), (Georgia), (China), (Belt, a...
# 20                           ((Metro, Manila), (Jan))
# 21                                 ((Dairy, Circle),)
# 22                                  ((European), (2))
# 23                        ((10), (Krishna), (Guntur))
# 24                               ((Andhra, Pradesh),)
# 25          ((AIIB), ($, 285, million), (Bangladesh))
# 26  ((AIIB), (Bangladesh, Independent, Power, Proj...
# 27           ((AIIB), (60, mln), (USD), (Bangladesh))
# 28                     ((AIIB), (60mn), (Bangladesh))
# 29                 ((AIIB), (Bangladesh, Bhola, IPP))
# ..                                                ...
# 56                     ((TAP, Gas, Pipeline), (2018))
# 57                     ((1.2B, euros), (TAP), (2018))
# 58                        ((1.2, bln, euros), (2018))
# 59         ((EIB), (130, mln, euro), (Serbia), (Nis))
# 60  ((Bulgarian), (EIB), (100, M, euro), (Juncker,...
# 61                                           ((EIB),)
# 62                                ((EIB), ($, 25, m))
# 63        ((EIB), (African), (d.light), (US$, 25, m))
# 64                                   ((EIB), (150mn))
# 65  ((Euro, 45, million), (European, Investment, B...
# 66           ((38), (Mln, for, Expansion), (Morocco))
# 67  ((AfDB), ($, 52.5, m), (Green, Climate, Fund, ...
# 68                                   ((IDB), (Quito))
# 69                       ((IDB), (USD, 250), (Quito))
# 70                ((IDB, Invest), (IFC), (Argentina))
# 71                               ((IDB), (Argentina))
# 72  ((IDB), (USD, 5, mn), (MONI, Online), (first),...
# 73  ((ADB), (India), ($, 120, Million), (Improve, ...
# 74            ((World, Bank), ($, 486, m), (Nigeria))
# 75  ((Inland, Waterways, Authority, Of, India), (J...
# 76              ((World, Bank), (420), (Maharashtra))
# 77  ((Burkina), (World, Bank, Approves), ($, 50, M...
# 78            ((World, Bank), ($, 180, mln), (Kenya))
# 79                        (($, 40, m), (World, Bank))
# 80                     ((Telkom, Kenya), (EIB), (75))
# 81  ((European, Investment, Bank), ($, 150, m), (P...
# 82       ((ADB), (World, Bank), (Australia), (Samoa))
# 83                         ((IDB), (1bn), (Colombia))
# 84  ((Inter, -, American, Development, Bank, Loans...
# 85                                  ((IDB), (Brazil))
#
#                                 article_text_entities  \
# 0   ((The, Asian, Development, Bank), (ADB), (toda...
# 1   ((KABUL), (AFGHANISTAN), (14, May, 2018), (The...
# 2   ((MANILA), (PHILIPPINES), (21), (February, 201...
# 3   ((The, Board, of, Directors), (the, Asian, Dev...
# 4   ((//es_subbox), (PremiumThe, Asian, Developmen...
# 5   ((The, Asian, Development, Bank), (ADB), ($, 2...
# 6   ((B.Grimm, Power), (ADB), (AseanADB), (Power, ...
# 7                                        ((Compelo),)
# 8   ((BANGKOK), (THAILAND), (23, February, 2018), ...
# 9   ((United, Nations), (Amina, Mohammed), (the, S...
# 10  ((TrendAsian, Infrastructure, Investment, Bank...
# 11  ((Dhaka), (Monday), (AIIB), ($, 285, million),...
# 12  ((DHAKA), (Feb, 26), (Reuters), (Beijing), (As...
# 13  ((DHAKA), (Reuters), (Beijing), (Asian, Infras...
# 14  ((Beijing), (Asian, Infrastructure, Investment...
# 15  ((Asian, Infrastructure, Investment, Bank), ($...
# 16  ((RepresentativePassed), (Andhra, Pradesh), (A...
# 17  ((AIIB), (140mn), (Madhya), (PradeshNew, Delhi...
# 18  ((Asian, Infrastructure, Investment, Bank), ($...
# 19  ((years), (Beijing), (Georgia), (Black, Sea), ...
# 20  ((MANILA), (500-million), (January), (the, Dep...
# 21  ((BENGALURU), (The, Bangalore, Metro, Rail, Co...
# 22  ((BENGALURU), (The, European, Investment, Bank...
# 23  ((10), (Krishna), (Guntur), (the, Detailed, Pr...
# 24  ((Express, News), (the, Andhra, Pradesh, Urban...
# 25  ((DHAKA), (Reuters), (Beijing), (Asian, Infras...
# 26  ((Afghanistan, Åland, Islands), (Albania), (Al...
# 27  ((DHAKA), (Feb., 26), (Xinhua, )), (The, Asian...
# 28  ((Beijing), (Asian, Infrastructure, Investment...
# 29  ((The, Asian, Infrastructure, Investment, Bank...
# ..                                                ...
# 56  ((TAP, Gas, Pipeline), (200), (The, European, ...
# 57  ((Baku), (Azerbaijan), (Feb.20By), (The, Europ...
# 58  ((BAKU), (Feb, 20), (Reuters), (The, European,...
# 59  ((EIB), (130, mln, euro), (Serbia), (Nis), (Di...
# 60  ((FacebookTwitterGoogleLinkedInRedditA, Europe...
# 61  ((Tuesday), (Mahendra, Jain), (Sunita, Lukkhoo...
# 62  ((The, European, Investment, Bank), (EIB), (25...
# 63  ((The, European, Investment, Bank), (EIB), (US...
# 64  ((New, Delhi), (Mar, 10), (PTI), (Indian, Rene...
# 65  ((Valmet, Oyj), (Finland), (Euro, 45, million)...
# 66  ((The, European, Bank, for, Reconstruction, an...
# 67  ((WorldStage, Newsonline–, Nigeria, ’s), (Muha...
# 68  ((Close, Methodology, &, ProceduresDefinitions...
# 69  ((The, Inter, -, American, Development, Bank),...
# 70  ((IDB, Invest), (IFC), (Achiras), (Cordoba), (...
# 71  ((IDB), (ArgentinaApril, 24, (, Renewables, No...
# 72  ((IDB, Invest), (the, Inter, -, American, Deve...
# 73  ((The, Asian, Development, Bank), (the, Govern...
# 74  ((The, World, Bank, (, WB), ($, 486, m), (the,...
# 75  ((the, Cabinet, Committee, on, Economic, Affai...
# 76  ((India), (Maharashtra), (the, World, Bank), (...
# 77  ((Today), (the, World, Bank), ($, 50, million)...
# 78  ((NAIROBI), (April, 30), (Reuters), (The, Worl...
# 79  ((General, News), (Tuesday), (13), (February, ...
# 80  ((–, 60, %), (Helios, Investment, Partners), (...
# 81  ((The, European, Investment, Bank), (EIB), ($,...
# 82  ((APIA), (SAMOA), (9, February, 2018), (The, A...
# 83  ((Inter, -, American, Development, Bank, ’s), ...
# 84  ((Banco, Davivienda), (Colombia), ($, 200, mil...
# 85  ((IDB, Invest), (the, Inter, -, American, Deve...
#
#                          Project Description_entities  \
# 0   ((the, Greater, Mekong, Subregion), (GMS), (SE...
# 1                       ((MFF), (MFF), (Afghanistan))
# 2   ((Bangladesh), (Asian, Development, Bank), (AD...
# 3   ((Bangladesh), (Asian, Development, Bank), (AD...
# 4   ((ADB), (Power, Public, Company, Limited), (th...
# 5   ((ADB), (Power, Public, Company, Limited), (th...
# 6   ((ADB), (Power, Public, Company, Limited), (th...
# 7   ((ADB), (Power, Public, Company, Limited), (th...
# 8   ((ADB), (Power, Public, Company, Limited), (th...
# 9   ((ADB), (Power, Public, Company, Limited), (th...
# 10  ((the, Trans, -, Anatolian, Natural, Gas, Pipe...
# 11  ((Titas, Gas, Field), (Chittagong), (Bakhrabad...
# 12  ((Titas, Gas, Field), (Chittagong), (Bakhrabad...
# 13  ((Titas, Gas, Field), (Chittagong), (Bakhrabad...
# 14  ((Titas, Gas, Field), (Chittagong), (Bakhrabad...
# 15  ((Titas, Gas, Field), (Chittagong), (Bakhrabad...
# 16  ((Project), (Amaravati, Capital, City), (AIIB)...
# 17  ((Project), (MPRRDA), (3), (1), (Rural, Connec...
# 18  ((Project), (MPRRDA), (3), (1), (Rural, Connec...
# 19  ((two), (14.3, km), (Batumi), (second), (Georg...
# 20  ((AIIB), (Metro), (Manila), (about, 56), (11,1...
# 21  ((North, -, South), (Central), (Eastern), (Ban...
# 22  ((North, -, South), (Central), (Eastern), (Ban...
# 23                                                 ()
# 24                                                 ()
# 25  ((AIIB), ($, 165, million), (the, Distribution...
# 26  ((The, Asian, Infrastructure, Investment, Bank...
# 27  ((The, Asian, Infrastructure, Investment, Bank...
# 28  ((The, Asian, Infrastructure, Investment, Bank...
# 29  ((The, Asian, Infrastructure, Investment, Bank...
# ..                                                ...
# 56  ((Turkey), (Shah, Deniz), (Azerbaijan), (Europ...
# 57  ((Turkey), (Shah, Deniz), (Azerbaijan), (Europ...
# 58  ((Turkey), (Shah, Deniz), (Azerbaijan), (Europ...
# 59  ((Nis, -, Dimitrovgrad), (96, km), (Nis), (22,...
# 60                 ((Huvepharma, International, 's),)
# 61  ((23, km), (about, 96), (Bangalore), (Karnatak...
# 62  ((about, 10, million), (Sub, -, Saharan, Afric...
# 63  ((about, 10, million), (Sub, -, Saharan, Afric...
# 64                                                 ()
# 65                               ((Valmet, Oyj, 's),)
# 66  ((Figeac, Aero, Group), (Figeac, Aero, Tunisie...
# 67  ((the, Republic, of, Zambia), (GRZ), (Independ...
# 68  ((22, km), (15), (Quito), (the, Metropolitan, ...
# 69  ((22, km), (15), (Quito), (the, Metropolitan, ...
# 70  ((The, Achiras, Wind, Power, Project), (47,25M...
# 71  ((The, Achiras, Wind, Power, Project), (47,25M...
# 72  ((Moni), (The, Inter, -, American, Investment,...
# 73  ((an, additional, 840, kilometers), (640, kilo...
# 74                                                 ()
# 75       ((1), (Farakka), (six), (five), (Ro, -, Ro))
# 76                    ((Maharashtra), (four), (C, )))
# 77                                                 ()
# 78                                                 ()
# 79  ((the, Secondary, Education, Improvement, Proj...
# 80  ((EIB), (3), (4), (FTTB, (, Fibre, To, The, Bu...
# 81              ((EIB), (Enel, Green, Power), (Peru))
# 82             ((ADB), (Samoa), (Fiji), (ICT), (ICT))
# 83  ((El, banco), (Empresas, Publicas, de, Medelli...
# 84  ((Priority, Housing), (Social, Housing), (VIS)...
# 85  ((Bozano, Investimentos, Growth, Capital, Fund...
#
#                                 Project Name_entities
# 0   ((Road, Network, Improvement, Project), (Secon...
# 1   ((Energy, Supply, Improvement, Investment, Pro...
# 2   ((Railway, Rolling, Stock, Operations, Improve...
# 3   ((Railway, Rolling, Stock, Operations, Improve...
# 4   ((ASEAN, Distributed, Power, Project, :, Initi...
# 5   ((ASEAN, Distributed, Power, Project, :, Initi...
# 6   ((ASEAN, Distributed, Power, Project, :, Initi...
# 7   ((ASEAN, Distributed, Power, Project, :, Initi...
# 8   ((ASEAN, Distributed, Power, Project, :, Initi...
# 9   ((ASEAN, Distributed, Power, Project, :, Initi...
# 10  ((Azerbaijan), (Trans, Anatolian, Natural, Gas...
# 11                                    ((Bangladesh),)
# 12                                    ((Bangladesh),)
# 13                                    ((Bangladesh),)
# 14                                    ((Bangladesh),)
# 15                                    ((Bangladesh),)
# 16                             ((India), (Amaravati))
# 17  ((India), (Madhya, Pradesh, Rural, Connectivit...
# 18  ((India), (Madhya, Pradesh, Rural, Connectivit...
# 19       ((Georgia), (Batumi, Bypass, Road, Project))
# 20  ((Philippines), (Metro, Manila, Flood, Managem...
# 21  ((India), (Bangalore, Metro, Rail, Project, -,...
# 22  ((India), (Bangalore, Metro, Rail, Project, -,...
# 23  ((India), (Andhra, Pradesh, Urban, Water, Supp...
# 24  ((India), (Andhra, Pradesh, Urban, Water, Supp...
# 25               ((Bangladesh), (Expansion, Project))
# 26                                    ((Bangladesh),)
# 27                                    ((Bangladesh),)
# 28                                    ((Bangladesh),)
# 29                                    ((Bangladesh),)
# ..                                                ...
# 56                                                 ()
# 57                                                 ()
# 58                                                 ()
# 59                          ((NIS, -, DIMITROVGRAD),)
# 60                                                 ()
# 61  ((Bangalore, Metro, Rail, Corporation, -, LINE...
# 62                                                 ()
# 63                                                 ()
# 64                                                 ()
# 65                    ((VALMET, -, AUTOMATION, RDI),)
# 66                        ((Figeac, Aero, Regional),)
# 67                                        ((Zambia),)
# 68  ((Quito, Metropolitan, Urban, Transport, Syste...
# 69  ((Quito, Metropolitan, Urban, Transport, Syste...
# 70                 ((Achiras, Wind, Power, Project),)
# 71                 ((Achiras, Wind, Power, Project),)
# 72                            ((Moni, Online, S.A.),)
# 73       ((Railway, Sector, Investment, Program, -),)
# 74     ((NG, -, Electricity, Transmission, Project),)
# 75                                                 ()
# 76                                                 ()
# 77                                       ((Burkina),)
# 78                    ((KenGen, Guarantee, Program),)
# 79  ((Secondary, Education, Improvement, Project, ...
# 80                     ((KENYA, TELECOM, EXPANSION),)
# 81                      ((ENEL, GREEN, POWER, PERU),)
# 82              ((Samoa, Submarine, Cable, Project),)
# 83               ((Planta, Hidroelectrica, Ituango),)
# 84                          ((Davivienda, Colombia),)
# 85                 ((Bozano, Growth, Capital, Fund),)
#
# [86 rows x 16 columns]

# %%
len(train_df[train_df.Matched == 0])
# Out:
# 0

# %%
train_df.iloc[0]
# Out:
# article_id                                                                10f9ed2
# ProjectNumber                                                       ADB-41123-015
# Matched                                                                         1
# article_text                    The Asian Development Bank (ADB) today signed ...
# article_keywords                [development, supply, tonle, million, infrastr...
# article_title                   ADB Provides Support for Three Infrastructure ...
# Project Description             The project aims to provide efficient transpor...
# Project Name                    Road Network Improvement Project (formerly Sec...
# article_title_nlp               (ADB, Provides, Support, for, Three, Infrastru...
# article_text_nlp                (The, Asian, Development, Bank, (, ADB, ), tod...
# Project Description_nlp         (The, project, aims, to, provide, efficient, t...
# Project Name_nlp                (Road, Network, Improvement, Project, (, forme...
# article_title_entities            ((Three, Infrastructure, Projects), (Cambodia))
# article_text_entities           ((The, Asian, Development, Bank), (ADB), (toda...
# Project Description_entities    ((the, Greater, Mekong, Subregion), (GMS), (SE...
# Project Name_entities           ((Road, Network, Improvement, Project), (Secon...
# Name: 0, dtype: object

# %%
text_ents_test = train_df['article_text_entities'].iloc[0]
proj_ents_test = train_df['Project Description_entities'].iloc[0]

# %%
ent_labels = [ent.label_ for ent in ents_test]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-421-83c4c8947716> in <module>()
# ----> 1 ent_labels = [ent.label_ for ent in ents_test]
#
# NameError: name 'ents_test' is not defined

# %%
for ent in doc.ents:
    print(ent.text, ent.label_)

# %%
len(train_df)
# Out:
# 86

# %%
train_df['article_text_entities'].iloc[0]
# Out:
# (The Asian Development Bank,
#  ADB,
#  today,
#  three,
#  the Government of Cambodia,
#  Tonle Sap,
#  Aun Pornmoniroth,
#  Ministry of Economy and Finance,
#  Cambodia,
#  Samiuela Tukuafu,
#  ADB Country,
#  Cambodia,
#  $70 million,
#  Road Network Improvement Project,
#  147-kilometer,
#  Prey Veng,
#  Siem Reap,
#  Svay Rieng,
#  the Ministry of Public Works and Transport,
#  The Provincial Water Supply,
#  Sanitation Project,
#  more than 209,000,
#  Battambang,
#  Kampong Cham,
#  Siem Reap,
#  Sihanoukville,
#  $50 million,
#  ADB,
#  $10 million,
#  the Japan Fund,
#  the Joint Crediting Mechanism,
#  the Government of Japan,
#  €40 million,
#  $43.5 million,
#  Agence Française de Développement,
#  €4.67 million,
#  $5.09 million,
#  the European Union’s,
#  Asia Investment Facility,
#  The Government of Cambodia,
#  $10.54 million,
#  ADB,
#  Smallholder Development Project,
#  Tonle Sap Basin’s,
#  Banteay Meanchey,
#  Kampong Cham,
#  Kampong Thom,
#  Siem Reap,
#  Tboung Khmum,
#  ADB,
#  $50 million,
#  $10 million,
#  the International Fund for Agricultural Development,
#  $6 million,
#  the Government of Cambodia)
